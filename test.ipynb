# %%
from face_roc import draw_on_frame , add_img2db , cheak_1face

# %%
add_img2db('face.jpg' , 'Mohammed')
add_img2db('face2.jpg' , 'Mohammed')
add_img2db('face3.jpg' , 'Mohammed')
# Out:
# "add_img2db" has completed with id: id_1 and label : Mohammed
# "add_img2db" has completed with id: id_2 and label : Mohammed
# "add_img2db" has completed with id: id_3 and label : Mohammed

# %%
cf1 =cheak_1face('huss.jpg')
cf1 # UnKnown
# Out:
# 0.806691245279221 0.3
# {'img': [{'verified': False, 'name': 'UnKnown'},
#   {'x': 334, 'y': 250, 'w': 344, 'h': 521}]}

# %%
cf1 =cheak_1face('face4.jpg')
cf1 # Mohammed
# Out:
# -2.220446049250313e-16 0.3
# {'img': [{'verified': True, 'name': 'Mohammed'},
#   {'x': 237, 'y': 186, 'w': 101, 'h': 142}]}

# %%
import cv2
import matplotlib.pyplot as plt

# %%
messi = cv2.imread('MESSI.jpg')

messi = draw_on_frame(messi)

plt.imshow(messi[: , : , ::-1])

plt.show()
# Out:
# 0.8423232725364644 0.3
